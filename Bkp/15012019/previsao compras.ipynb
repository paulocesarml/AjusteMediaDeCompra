# %% [markdown]
# <h1>Projeto De Previsao de Compras</h1>
# <h2>Versao.: 1.2</h2>
# <h2>Data.:   14/12/2018  17:20</h2>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
from math import sqrt
from sklearn.metrics import mean_squared_error 

dateparse = lambda dates: pd.datetime.strptime(dates, '%d.%m.%Y %H:%M:%S')
dataFrame = pd.read_csv(r"C:\Macros\EMS-GERMED.CSV", 
                        sep=";", parse_dates = ['dt_venda'], index_col = 'dt_venda', date_parser = dateparse)

# %%
dataFrame.head()
# Out:
#             cd_empresa  cd_mercadoria  qt_vendida
# dt_venda
# 2014-01-01           1         117661         382
# 2014-02-01           1         117661         325
# 2014-03-01           1         117661         715
# 2014-04-01           1         117661         300
# 2014-05-01           1         117661          81

# %% [raw]
# dataFrame[(dataFrame['cd_mercadoria'] == 117661) & (dataFrame['cd_empresa'] == 1)].sort_values(by=['dt_venda'],ascending=False)

# %%
def buscarDataAtual():
    data_atual = datetime.today()
    data_em_texto = '{}-{}-{}'.format(data_atual.year, data_atual.month, '01')
    return data_em_texto

# %%
def calcularErro(dataAtual):
    for i, df in enumerate(arrayDeDataFrame):
        if (len(df) > 7):
            aVendida = df.iloc[-6:, 3].values
            j = 1
            while j <= 12:
                aMM = df.iloc[-8:-2, j+2].values
                erroMM = sqrt(mean_squared_error(aVendida, aMM))
                df.loc[dataAtual, 'MM'+str(j)] = erroMM
                j+=1

# %%
def adicionarIndicesFaltantes(df):
    idx = pd.date_range(min(df.index), dataAtual, freq='MS')
    df.index = pd.DatetimeIndex(df.index)
    df = df.reindex(idx, fill_value=0)
    return df

# %%
def calcularMediaMovel(arrayDeDataFrame):
    j = 1
    while j <= 12:
        arrayDeDataFrame[len(arrayDeDataFrame)-1]['MM'+str(j)] = arrayDeDataFrame[len(arrayDeDataFrame)-1]['qt_vendida'].rolling(j).mean()
        j += 1
    return arrayDeDataFrame

# %%
#dataFrame.drop(index=dataFrame.loc[dataFrame['dt_venda'] == '2018-01-11'].index)
#df = df.drop(df[df.score < 50].index)
dataAtual = buscarDataAtual()
dataFrame = dataFrame[dataFrame.index != dataAtual]

# %%
arrayMercadoria = dataFrame['cd_mercadoria'].unique()
arrayEmpresa = [1, 4, 5]
#arrayMercadoria = [117661]
#arrayEmpresa = [1]

arrayDeDataFrame = []

for emp in arrayEmpresa:
    i = 0
    for i, mer in enumerate(arrayMercadoria):
        df = dataFrame[(dataFrame['cd_mercadoria'] == mer) & 
                      (dataFrame['cd_empresa'] == emp)].sort_values(by=['dt_venda'],ascending=True)
        
        if (len(df) > 0):
            df = adicionarIndicesFaltantes(df) 
            arrayDeDataFrame.append(df)                
            arrayDeDataFrame = calcularMediaMovel(arrayDeDataFrame)
            
            
        arrayDeDataFrame[len(arrayDeDataFrame)-1].fillna(0, inplace=True)
         
calcularErro(dataAtual)

# %%
arrayDeDataFrame[356]
# Out:
#             cd_empresa  cd_mercadoria  qt_vendida   MM1   MM2        MM3  \
# 2014-04-01           1         330201          52  52.0   0.0   0.000000
# 2014-05-01           1         330201          41  41.0  46.5   0.000000
# 2014-06-01           1         330201          -1  -1.0  20.0  30.666667
# 2014-07-01           0              0           0   0.0  -0.5  13.333333
# 2016-02-01  23.181818  25.500000
# 2016-03-01  20.181818  21.250000
# 2016-04-01  18.181818  18.500000
# 2016-05-01  15.909091  16.666667
# 2016-06-01  13.272727  14.583333
# 2016-07-01   9.909091  12.166667
# 2016-08-01   6.454545   9.083333
# 2016-09-01   2.454545   5.916667
# 2016-10-01   0.545455   2.250000
# 2016-11-01   0.545455   0.500000
# 2016-12-01   0.000000   0.500000
# 2017-01-01   0.000000   0.000000
# 2017-02-01   0.000000   0.000000
# 2017-03-01   0.000000   0.000000
# 2017-04-01   0.000000   0.000000
# 2017-05-01   0.000000   0.000000
# 2017-06-01   0.000000   0.000000
# 2017-07-01   0.000000   0.000000
# 2017-08-01   0.000000   0.000000
# 2017-09-01   0.000000   0.000000
# 2017-10-01   0.000000   0.000000
# 2017-11-01   0.000000   0.000000
# 2017-12-01   0.000000   0.000000
# 2018-01-01   0.000000   0.000000
# 2018-02-01   0.000000   0.000000
# 2018-03-01   0.000000   0.000000
# 2018-04-01   0.000000   0.000000
# 2018-05-01   0.000000   0.000000
# 2018-06-01   0.000000   0.000000
# 2018-07-01   0.000000   0.000000
# 2018-08-01   0.000000   0.000000
# 2018-09-01   0.000000   0.000000
# 2018-10-01   0.000000   0.000000
# 2018-11-01   0.000000   0.000000
# 2018-12-01   0.000000   0.000000

# %%
min(dict(arrayDeDataFrame[356].iloc[-1, 4:]), key=dict(arrayDeDataFrame[356].iloc[-1, 4:]).get)
# Out:
# 'MM2'

# %%
arrayDeDataFrame[356][min(dict(arrayDeDataFrame[356].iloc[-1, 4:]), 
                        key=dict(arrayDeDataFrame[356].iloc[-1, 4:]).get)][len(arrayDeDataFrame[356])-2]
# Out:
# 0.0

# %%
resultados = []

for i in range(0, len(arrayDeDataFrame)):
    modelo = min(dict(arrayDeDataFrame[i].iloc[-1, 4:]), key=dict(arrayDeDataFrame[i].iloc[-1, 4:]).get)
    qt_previsao = arrayDeDataFrame[i][min(dict(arrayDeDataFrame[i].iloc[-1, 4:]), key=dict(arrayDeDataFrame[i].iloc[-1, 4:]).get)][len(arrayDeDataFrame[i])-2]
    erro = arrayDeDataFrame[i][min(dict(arrayDeDataFrame[i].iloc[-1, 4:]), key=dict(arrayDeDataFrame[i].iloc[-1, 4:]).get)][len(arrayDeDataFrame[i])-1]
    dt_previsao = arrayDeDataFrame[i].index[-1]
    cod_mercadoria = arrayDeDataFrame[i].iloc[:,1].unique().max()
    cod_empresa = arrayDeDataFrame[i].iloc[:,0].unique().max()
    lista = [modelo, qt_previsao, dt_previsao, cod_mercadoria, cod_empresa, erro ]
    resultados.append(lista)

    
dfR = pd.DataFrame(resultados,columns=['modelo', 'qt_previsao', 'dt_previsao', 'cd_mercadoria','cd_empresa', 'RMSE'])
dfR
# Out:
#      modelo  qt_previsao dt_previsao  cd_mercadoria  cd_empresa         RMSE
# 0       MM5   318.800000  2018-12-01         117661           1   181.453825
# 1       MM2   297.500000  2018-12-01         117679           1   200.610430
# 2       MM2   550.500000  2018-12-01         117687           1  2044.825722
# 3       MM2   147.500000  2018-12-01         117700           1   117.778385
# 4       MM5   366.800000  2018-12-01         117718           1   211.825752
# 5      MM10    46.100000  2018-12-01         117726           1    26.825849
# 6      MM10   571.100000  2018-12-01         118120           1   279.267835
# 7       MM5   111.600000  2018-12-01         118138           1    80.992496
# 8      MM10   142.800000  2018-12-01         120795           1    69.879332
