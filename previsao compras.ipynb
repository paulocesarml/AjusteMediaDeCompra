# %% [markdown]
# <h1>Projeto De Previsao de Compras</h1>
# <h2>Versao.: 1.2</h2>
# <h2>Data.:   14/12/2018  17:20</h2>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta
from math import sqrt
from sklearn.metrics import mean_squared_error 

dateparse = lambda dates: pd.datetime.strptime(dates, '%d.%m.%Y %H:%M:%S')
dataFrame = pd.read_csv(r"C:\Users\PC\Estudos\Data Science\Ajuste Media de Compra\datasets\VENDA-GAM-343.CSV", 
                        sep=";", parse_dates = ['dt_venda'], index_col = 'dt_venda', date_parser = dateparse)

# %%
dataFrame.head()
# Out:
#             cd_empresa  cd_mercadoria  qt_vendida
# dt_venda
# 2016-01-01           1         117661         616
# 2016-02-01           1         117661         207
# 2016-03-01           1         117661         584
# 2016-04-01           1         117661         236
# 2016-05-01           1         117661        1002

# %% [raw]
# dataFrame[(dataFrame['cd_mercadoria'] == 117661) & (dataFrame['cd_empresa'] == 1)].sort_values(by=['dt_venda'],ascending=False)

# %%
def buscarDataAtual():
    data_atual = datetime.today()
    data_em_texto = '{}-{}-{}'.format(data_atual.year, data_atual.month, '01')
    return data_em_texto

# %%
def calcularErro(dataAtual):
    for i, df in enumerate(arrayDeDataFrame):
        if (len(df) > 7):
            aVendida = df.iloc[-6:, 3].values
            j = 1
            while j <= 12:
                aMM = df.iloc[-8:-2, j+2].values
                erroMM = sqrt(mean_squared_error(aVendida, aMM))
                df.loc[dataAtual, 'MM'+str(j)] = erroMM
                j+=1

# %%
def adicionarIndicesFaltantes(df):
    idx = pd.date_range(min(df.index), dataAtual, freq='MS')
    df.index = pd.DatetimeIndex(df.index)
    df = df.reindex(idx, fill_value=0)
    return df

# %%
def calcularMediaMovel(arrayDeDataFrame):
    j = 1
    while j <= 12:
        arrayDeDataFrame[len(arrayDeDataFrame)-1]['MM'+str(j)] = \
            arrayDeDataFrame[len(arrayDeDataFrame)-1]['qt_vendida'].rolling(j).mean()
        j += 1
    return arrayDeDataFrame

# %%
#dataFrame.drop(index=dataFrame.loc[dataFrame['dt_venda'] == '2018-01-11'].index)
#df = df.drop(df[df.score < 50].index)
dataAtual = buscarDataAtual()
dataFrame = dataFrame[dataFrame.index != dataAtual]

# %%
arrayMercadoria = dataFrame['cd_mercadoria'].unique()
arrayEmpresa = [1, 4, 5]
#arrayMercadoria = [117661]
#arrayEmpresa = [1]

arrayDeDataFrame = []

for emp in arrayEmpresa:
    i = 0
    for i, mer in enumerate(arrayMercadoria):
        df = dataFrame[(dataFrame['cd_mercadoria'] == mer) & 
                      (dataFrame['cd_empresa'] == emp)].sort_values(by=['dt_venda'],ascending=True)
        
        if (len(df) > 0):
            df = adicionarIndicesFaltantes(df) 
            arrayDeDataFrame.append(df)                
            arrayDeDataFrame = calcularMediaMovel(arrayDeDataFrame)
            
            
        arrayDeDataFrame[len(arrayDeDataFrame)-1].fillna(0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-36f11ca336e7> in <module>
#      15             df = adicionarIndicesFaltantes(df)
#      16             arrayDeDataFrame.append(df)
# ---> 17             arrayDeDataFrame = calcularMediaMovel(arrayDeDataFrame)
#      18
#      19
#
# <ipython-input-16-1ecd76b2cdfe> in calcularMediaMovel(arrayDeDataFrame)
#       3     while j <= 12:
#       4         arrayDeDataFrame[len(arrayDeDataFrame)]['MM'+str(j)] = \
# ----> 5             arrayDeDataFrame[len(arrayDeDataFrame)]['qt_vendida'].rolling(j).mean()
#       6         j += 1
#       7     return arrayDeDataFrame
#
# IndexError: list index out of range

# %%
arrayDeDataFrame[0]
# Out:
#             cd_empresa  cd_mercadoria  qt_vendida          MM1         MM2  \
# 2016-01-01           1         117661         616   616.000000    0.000000
# 2016-02-01           1         117661         207   207.000000  411.500000
# 2016-03-01           1         117661         584   584.000000  395.500000
# 2016-04-01           1         117661         236   236.000000  410.000000
# 2016-05-01           1         117661        1002  1002.000000  619.000000
# 2016-06-01           1         117661         261   261.000000  631.500000
# 2016-07-01           1         117661         974   974.000000  617.500000
# 2016-08-01           1         117661         524   524.000000  749.000000
# 2016-09-01           0              0           0     0.000000  262.000000
# 2016-10-01           0              0           0     0.000000    0.000000
# 2016-11-01           1         117661         906   906.000000  453.000000
# 2016-12-01           1         117661         713   713.000000  809.500000
# 2017-01-01           1         117661         788   788.000000  750.500000
# 2017-02-01           1         117661         494   494.000000  641.000000
# 2017-03-01           1         117661         868   868.000000  681.000000
# 2017-04-01           1         117661         500   500.000000  684.000000
# 2017-05-01           1         117661         645   645.000000  572.500000
# 2017-06-01           1         117661         632   632.000000  638.500000
# 2017-07-01           1         117661         365   365.000000  498.500000
# 2017-08-01           1         117661        1070  1070.000000  717.500000
# 2017-09-01           1         117661         469   469.000000  769.500000
# 2017-10-01           1         117661         219   219.000000  344.000000
# 2017-11-01           1         117661        1289  1289.000000  754.000000
# 2017-12-01           1         117661         165   165.000000  727.000000
# 2018-01-01           1         117661         609   609.000000  387.000000
# 2018-02-01           1         117661         548   548.000000  578.500000
# 2018-03-01           1         117661         299   299.000000  423.500000
# 2018-04-01           1         117661         503   503.000000  401.000000
# 2018-05-01           1         117661         292   292.000000  397.500000
# 2018-06-01           1         117661         422   422.000000  357.000000
# 2018-07-01           1         117661         437   437.000000  429.500000
# 2018-08-01           1         117661         393   393.000000  415.000000
# 2018-09-01           1         117661         442   442.000000  417.500000
# 2018-10-01           1         117661         322   322.000000  382.000000
# 2018-11-01           1         117661         250   250.000000  286.000000
# 2018-12-01           1         117661         488   488.000000  369.000000
# 2019-01-01           1         117661        1050  1050.000000  769.000000
# 2019-02-01           0              0           0   397.414561  324.705222
#
#                    MM3         MM4         MM5         MM6         MM7  \
# 2016-01-01    0.000000    0.000000    0.000000    0.000000    0.000000
# 2016-02-01    0.000000    0.000000    0.000000    0.000000    0.000000
# 2016-03-01  469.000000    0.000000    0.000000    0.000000    0.000000
# 2016-04-01  342.333333  410.750000    0.000000    0.000000    0.000000
# 2016-05-01  607.333333  507.250000  529.000000    0.000000    0.000000
# 2016-06-01  499.666667  520.750000  458.000000  484.333333    0.000000
# 2016-07-01  745.666667  618.250000  611.400000  544.000000  554.285714
# 2016-08-01  586.333333  690.250000  599.400000  596.833333  541.142857
# 2016-09-01  499.333333  439.750000  552.200000  499.500000  511.571429
# 2017-10-01  596.00000  584.666667  605.000000  614.818182  639.083333
# 2017-11-01  648.62500  673.000000  655.100000  667.181818  671.000000
# 2017-12-01  606.75000  594.888889  622.200000  610.545455  625.333333
# 2018-01-01  602.25000  607.000000  596.300000  621.000000  610.416667
# 2018-02-01  591.75000  596.222222  601.100000  591.909091  614.916667
# 2018-03-01  583.50000  559.222222  566.500000  573.636364  567.500000
# 2018-04-01  512.62500  574.555556  553.600000  560.727273  567.750000
# 2018-05-01  490.50000  488.111111  546.300000  529.818182  538.333333
# 2018-06-01  515.87500  482.888889  481.500000  535.000000  520.833333
# 2018-07-01  409.37500  507.111111  478.300000  477.454545  526.833333
# 2018-08-01  437.87500  407.555556  495.700000  470.545455  470.416667
# 2018-09-01  417.00000  438.333333  411.000000  490.818182  468.166667
# 2018-10-01  388.75000  406.444444  426.700000  402.909091  476.750000
# 2018-11-01  382.62500  373.333333  390.800000  410.636364  390.166667
# 2018-12-01  380.75000  394.333333  384.800000  399.636364  417.083333
# 2019-01-01  475.50000  455.111111  459.900000  445.272727  453.833333
# 2019-02-01  288.06772  291.995215  287.480967  287.908386  292.322410

# %%
min(dict(arrayDeDataFrame[356].iloc[-1, 4:]), key=dict(arrayDeDataFrame[356].iloc[-1, 4:]).get)
# Out:
# 'MM2'

# %%
arrayDeDataFrame[356][min(dict(arrayDeDataFrame[356].iloc[-1, 4:]), 
                        key=dict(arrayDeDataFrame[356].iloc[-1, 4:]).get)][len(arrayDeDataFrame[356])-2]
# Out:
# 0.0

# %%
resultados = []

for i in range(0, len(arrayDeDataFrame)):
    modelo = min(dict(arrayDeDataFrame[i].iloc[-1, 4:]), key=dict(arrayDeDataFrame[i].iloc[-1, 4:]).get)
    qt_previsao = arrayDeDataFrame[i][min(dict(arrayDeDataFrame[i].iloc[-1, 4:]), key=dict(arrayDeDataFrame[i].iloc[-1, 4:]).get)][len(arrayDeDataFrame[i])-2]
    erro = arrayDeDataFrame[i][min(dict(arrayDeDataFrame[i].iloc[-1, 4:]), key=dict(arrayDeDataFrame[i].iloc[-1, 4:]).get)][len(arrayDeDataFrame[i])-1]
    dt_previsao = arrayDeDataFrame[i].index[-1]
    cod_mercadoria = arrayDeDataFrame[i].iloc[:,1].unique().max()
    cod_empresa = arrayDeDataFrame[i].iloc[:,0].unique().max()
    lista = [modelo, qt_previsao, dt_previsao, cod_mercadoria, cod_empresa, erro ]
    resultados.append(lista)

    
dfR = pd.DataFrame(resultados,columns=['modelo', 'qt_previsao', 'dt_previsao', 'cd_mercadoria','cd_empresa', 'RMSE'])
dfR
# Out:
#      modelo  qt_previsao dt_previsao  cd_mercadoria  cd_empresa         RMSE
# 0       MM5   318.800000  2018-12-01         117661           1   181.453825
# 1       MM2   297.500000  2018-12-01         117679           1   200.610430
# 2       MM2   550.500000  2018-12-01         117687           1  2044.825722
# 3       MM2   147.500000  2018-12-01         117700           1   117.778385
# 4       MM5   366.800000  2018-12-01         117718           1   211.825752
# 5      MM10    46.100000  2018-12-01         117726           1    26.825849
# 6      MM10   571.100000  2018-12-01         118120           1   279.267835
# 7       MM5   111.600000  2018-12-01         118138           1    80.992496
# 8      MM10   142.800000  2018-12-01         120795           1    69.879332
# 9      MM10  3161.400000  2018-12-01         126652           1  1615.616815
# 10      MM8     1.375000  2018-12-01         126660           1     2.092454
